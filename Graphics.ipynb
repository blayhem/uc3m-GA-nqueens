# %% [markdown]
# ## Graficos para el report

# %% [markdown]
# ### Versión 1

# %%
# from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

plt.plot([i for i in range(4,13)], [7.9,15,159.6,91.4,706.2,1183.2,4384.5,11681.1,27614.3], label='Evaluaciones')
plt.plot([i for i in range(4,13)], [11.2,17.4,174.2,88,554.9,872,3102.2,8140.9,19085.8], label='Ciclos')

# title = 'N={}, K={}, L={}, p. de mutación={}, p. de cruce={}'.format(self.N, self.K, self.L, self.pm, self.pc)
# plt.title(title)
# plt.ylabel('')
plt.xlabel('N')
plt.legend()
plt.show()

# %% [markdown]
# ### Versión 2

# %%
import matplotlib.pyplot as plt

evals2  = [24.0,88.9,162.9,209.9,353.9,677.1,1293.5,6107.3,10495.9,23343.6,34762.8,165205.7,368870.4]
ciclos2 = [1.0,1.0,1.4,1.6,1.5,6.4,15.7,29.5,130.2,293.0,436.2,2072.4,4626.7]

plt.plot([i for i in range(4,13)], evals2[:9], label='Evaluaciones')
plt.plot([i for i in range(4,13)], ciclos2[:9], label='Ciclos')

# title = 'N={}, K={}, L={}, p. de mutación={}, p. de cruce={}'.format(self.N, self.K, self.L, self.pm, self.pc)
# plt.title(title)
# plt.ylabel('')
plt.xlabel('N')
plt.legend()
plt.show()


plt.plot([i for i in range(4,13)], ciclos2[:9], label='Ciclos')
plt.xlabel('N')
plt.legend()
plt.show()

# %% [markdown]
# ### Codificación binaria

# %%
import matplotlib.pyplot as plt

evals  = [298.3,744.4,31652.3,17754.9,61845.6,142654.6,461264.8,668845.6,437959.6]
ciclos = [4.6,30.2,574.8,304.3,953.4,2146.7,6741.7,9701.7,6371.0]
'''
plt.plot([i for i in range(4,13)], evals[:9], label='Evaluaciones')
plt.xlabel('N')
plt.legend()
plt.show()

plt.plot([i for i in range(4,13)], ciclos[:9], '#EF8536',label='Ciclos')

plt.xlabel('N')
plt.legend()
plt.show()
'''

print('''
    datos buenos
    ''')
evals  = [359.4,532.3,23410.5,54043.3,54043.3,97136.1,95453.4,355590.2,418412.0,720438.2]
ciclos = [7.8,11.7,443.6,867.0,1468.2,1448.1,5220.1,6079.6,10402.6]

plt.plot([i for i in range(4,13)], evals[:9], label='Evaluaciones')
plt.xlabel('N')
plt.legend()
plt.show()

plt.plot([i for i in range(4,13)], ciclos[:9], '#EF8536',label='Ciclos')

plt.xlabel('N')
plt.legend()
plt.show()
# Out:
#     datos buenos

# %% [markdown]
# ### Fuerza bruta

# %%
import matplotlib.pyplot as plt

ciclos = [26,15,171,42,876,333,975,517,3066,1365,26495,20280,160712,91222,743229,48184,3992510,179592,179592,584591, 9878316,1216775,10339849,12263400]
plt.plot([i for i in range(4,len(ciclos)+4)], ciclos, label='Ciclos')

# asdf = 'N=4-'+str(len(ciclos)+4)
# plt.title(asdf)
plt.xlabel('N')
plt.legend()
plt.show()

# %% [markdown]
# ### Fuerza bruta detalle

# %%
import matplotlib.pyplot as plt

ciclos = [26,15,171,42,876,333,975,517,3066,1365,26495,20280,160712,91222,743229,48184,3992510,179592,179592,584591, 9878316,1216775,10339849,12263400]


plt.plot([i for i in range(4,13)], ciclos[:9], label='Ciclos')
plt.suptitle('Detalle de N=4-12')
plt.xlabel('N')
plt.legend()
plt.show()
